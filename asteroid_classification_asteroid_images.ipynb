# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

DATA_DIR = 'asteroid_images_cropped'
if not os.path.exists(DATA_DIR):
    os.makedirs(DATA_DIR)
    print(f"Directory '{DATA_DIR}' created.")
else:
    print(f"Directory '{DATA_DIR}' already exists.")
# Out:
# Directory 'asteroid_images_cropped' already exists.

# %%
import os

DATA_DIR = 'asteroid_images_cropped'
classes = ['S_type', 'C_type', 'M_type']

for class_name in classes:
    class_dir = os.path.join(DATA_DIR, class_name)
    if not os.path.exists(class_dir):
        os.makedirs(class_dir)
        print(f"Directory '{class_dir}' created.")
    else:
        print(f"Directory '{class_dir}' already exists.")
# Out:
# Directory 'asteroid_images_cropped/S_type' created.
# Directory 'asteroid_images_cropped/C_type' created.
# Directory 'asteroid_images_cropped/M_type' created.

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image

# ------------------------
# Paths and parameters
# ------------------------
DATA_DIR = 'asteroid_images_cropped'  # Folder should have subfolders (one per class)
IMG_SIZE = (512, 512)
BATCH_SIZE = 16
EPOCHS = 100

# ------------------------
# Data generators
# ------------------------
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generator = train_datagen.flow_from_directory(
    DATA_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    DATA_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

# Number of classes (automatically detected from folders)
num_classes = len(train_generator.class_indices)
print("Classes found:", train_generator.class_indices)

# ------------------------
# Model definition
# ------------------------
model = Sequential([
    tf.keras.Input(shape=(*IMG_SIZE, 3)),     # ✅ Proper input layer
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')   # ✅ Matches detected classes
])

model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# ------------------------
# Training
# ------------------------
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator
)

# ------------------------
# Save model
# ------------------------
model.save('asteroid_classifier_model.h5')

# ------------------------
# Prediction function
# ------------------------
def predict_asteroid(img_path):
    img = image.load_img(img_path, target_size=IMG_SIZE)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0) / 255.0
    preds = model.predict(x)
    classes = list(train_generator.class_indices.keys())
    predicted_class = classes[np.argmax(preds)]
    confidence = np.max(preds)
    return predicted_class, confidence

# Example usage:
# result, conf = predict_asteroid('test_image.jpg')
# print(f'Predicted class: {result} (confidence: {conf:.2f})')
# Out:
# Found 23 images belonging to 6 classes.
# Found 5 images belonging to 6 classes.
# Classes found: {'C-Type': 0, 'C_type': 1, 'M-Type': 2, 'M_type': 3, 'S-Type': 4, 'S_type': 5}
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 15s 9s/step - accuracy: 0.1636 - loss: 14.0435 - val_accuracy: 0.8000 - val_loss: 8.0425
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 0.4907 - loss: 8.5776 - val_accuracy: 0.8000 - val_loss: 6.6591
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 6s/step - accuracy: 0.6141 - loss: 5.6759 - val_accuracy: 0.4000 - val_loss: 4.2678
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 13s/step - accuracy: 0.5643 - loss: 5.2214 - val_accuracy: 0.6000 - val_loss: 1.7749
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.5725 - loss: 2.7040 - val_accuracy: 0.6000 - val_loss: 0.6615
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 0.6431 - loss: 2.5650 - val_accuracy: 0.6000 - val_loss: 0.5244
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 0.9004 - loss: 0.4338 - val_accuracy: 1.0000 - val_loss: 0.4811
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 5s/step - accuracy: 1.0000 - loss: 0.4040 - val_accuracy: 1.0000 - val_loss: 0.2496
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 0.9710 - loss: 0.2630 - val_accuracy: 1.0000 - val_loss: 0.1444
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 6s/step - accuracy: 0.9502 - loss: 0.2304 - val_accuracy: 1.0000 - val_loss: 0.0807
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 6s/step - accuracy: 0.9212 - loss: 0.1529 - val_accuracy: 1.0000 - val_loss: 0.0356
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 8s/step - accuracy: 0.9420 - loss: 0.1711 - val_accuracy: 1.0000 - val_loss: 0.0299
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - accuracy: 0.8714 - loss: 2.0842 - val_accuracy: 1.0000 - val_loss: 0.0169
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 8s/step - accuracy: 0.9710 - loss: 0.1783 - val_accuracy: 1.0000 - val_loss: 0.0123
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 7s/step - accuracy: 1.0000 - loss: 0.0671 - val_accuracy: 1.0000 - val_loss: 0.0131
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 0.8505 - loss: 0.1878 - val_accuracy: 1.0000 - val_loss: 0.0153
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 1.0000 - loss: 0.0296 - val_accuracy: 1.0000 - val_loss: 0.0181
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0875 - val_accuracy: 1.0000 - val_loss: 0.0203
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 0.9234 - loss: 0.1395 - val_accuracy: 1.0000 - val_loss: 0.0146
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 14s 7s/step - accuracy: 0.9212 - loss: 0.0838 - val_accuracy: 1.0000 - val_loss: 0.0101
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0408 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0567 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 9s/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 5s/step - accuracy: 0.9502 - loss: 0.1121 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 8s/step - accuracy: 0.9234 - loss: 0.0878 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 1.0000 - loss: 0.0178 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0570 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 5s/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 5s/step - accuracy: 1.0000 - loss: 0.0318 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0664 - val_accuracy: 1.0000 - val_loss: 7.8128e-04
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 8s/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 5.3459e-04
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 8s/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 4.4228e-04
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 1.0000 - loss: 4.2605e-04 - val_accuracy: 1.0000 - val_loss: 4.0062e-04
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 3.8004e-04
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 3.5881e-04
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 6s/step - accuracy: 1.0000 - loss: 0.0257 - val_accuracy: 1.0000 - val_loss: 3.4089e-04
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 6s/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 3.2937e-04
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 15s 11s/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 1.0000 - val_loss: 3.0561e-04
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 8s/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 2.7642e-04
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 8s/step - accuracy: 0.9710 - loss: 0.4473 - val_accuracy: 1.0000 - val_loss: 2.9021e-04
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 22s 5s/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 3.0649e-04
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 0.9710 - loss: 0.0665 - val_accuracy: 1.0000 - val_loss: 2.9780e-04
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 2.8553e-04
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 6s/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 2.7522e-04
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 7s/step - accuracy: 1.0000 - loss: 0.0529 - val_accuracy: 1.0000 - val_loss: 2.8153e-04
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 7s/step - accuracy: 1.0000 - loss: 1.8948e-04 - val_accuracy: 1.0000 - val_loss: 3.0575e-04
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 1.0000 - val_loss: 3.1940e-04
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 0.9710 - loss: 0.1044 - val_accuracy: 1.0000 - val_loss: 3.3967e-04
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 26s 12s/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 1.0000 - val_loss: 3.5048e-04
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 14s 9s/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 3.3462e-04
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 9s/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 3.0949e-04
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 5s/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 1.0000 - val_loss: 3.1513e-04
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 5s/step - accuracy: 1.0000 - loss: 0.0618 - val_accuracy: 1.0000 - val_loss: 4.4637e-04
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 1.0000 - val_loss: 4.9837e-04
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 7s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 4.2253e-04
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 1.0000 - loss: 0.0284 - val_accuracy: 1.0000 - val_loss: 1.8224e-04
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 1.0000 - val_loss: 1.9716e-04
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 1.8238e-04
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 6.4917e-04 - val_accuracy: 1.0000 - val_loss: 1.6701e-04
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 5s/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 1.4469e-04
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 1.2169e-04
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 1.0224e-04
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 9s/step - accuracy: 1.0000 - loss: 0.0229 - val_accuracy: 1.0000 - val_loss: 7.6642e-05
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 8s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 6.1911e-05
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step - accuracy: 1.0000 - loss: 0.0165 - val_accuracy: 1.0000 - val_loss: 4.8800e-05
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 1.0000 - loss: 0.0202 - val_accuracy: 1.0000 - val_loss: 3.6261e-05
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 8s/step - accuracy: 1.0000 - loss: 6.8054e-04 - val_accuracy: 1.0000 - val_loss: 2.8132e-05
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 14s 9s/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 2.2601e-05
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 8s/step - accuracy: 1.0000 - loss: 2.6998e-05 - val_accuracy: 1.0000 - val_loss: 1.8763e-05
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 1.5568e-05
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 1.2564e-05
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 3.3643e-04 - val_accuracy: 1.0000 - val_loss: 1.0299e-05
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 8.5829e-06
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 0.9710 - loss: 0.0318 - val_accuracy: 1.0000 - val_loss: 7.7485e-06
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 5s/step - accuracy: 0.9502 - loss: 0.0502 - val_accuracy: 1.0000 - val_loss: 7.4147e-06
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 8s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 6.9856e-06
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 7.0809e-06
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 6.7948e-06
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 1.0000 - loss: 6.1573e-04 - val_accuracy: 1.0000 - val_loss: 6.5088e-06
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 5s/step - accuracy: 0.9502 - loss: 0.1182 - val_accuracy: 1.0000 - val_loss: 1.1325e-05
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 5.3066e-05 - val_accuracy: 1.0000 - val_loss: 1.7857e-05
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 2.6034e-05
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 9s/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 1.0000 - val_loss: 3.3472e-05
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 8s/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 3.8002e-05
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 8s/step - accuracy: 1.0000 - loss: 0.0233 - val_accuracy: 1.0000 - val_loss: 3.2781e-05
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 2.4783e-04 - val_accuracy: 1.0000 - val_loss: 3.0802e-05
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0193 - val_accuracy: 1.0000 - val_loss: 2.7798e-05
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 5s/step - accuracy: 1.0000 - loss: 3.8786e-04 - val_accuracy: 1.0000 - val_loss: 2.4103e-05
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 4.2276e-04 - val_accuracy: 1.0000 - val_loss: 2.1433e-05
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 1.0000 - loss: 0.0180 - val_accuracy: 1.0000 - val_loss: 1.8429e-05
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 9s/step - accuracy: 1.0000 - loss: 5.4408e-05 - val_accuracy: 1.0000 - val_loss: 1.5640e-05
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 5s/step - accuracy: 0.9710 - loss: 0.0298 - val_accuracy: 1.0000 - val_loss: 1.3041e-05
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 27s 10s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 1.1229e-05
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 10s/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 9.6797e-06
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 0.9234 - loss: 0.1241 - val_accuracy: 1.0000 - val_loss: 8.8452e-06
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 6s/step - accuracy: 1.0000 - loss: 6.1547e-04 - val_accuracy: 1.0000 - val_loss: 8.2969e-06
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 9s/step - accuracy: 0.9710 - loss: 0.0930 - val_accuracy: 1.0000 - val_loss: 7.4624e-06
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 8s/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 7.0810e-06
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 1.0000 - loss: 2.1711e-05 - val_accuracy: 1.0000 - val_loss: 6.9856e-06
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 1.0000 - loss: 8.9697e-04 - val_accuracy: 1.0000 - val_loss: 7.0095e-06
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
result = predict_asteroid('/content/asteroid_images_cropped/C-Type/test_image.jpg')
print('Predicted class:', result)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# Predicted class: ('M-Type', np.float32(0.99995995))

# %%
import cv2
import os
from pathlib import Path

# ---- Cropping function ----
def crop_black_borders(input_path, output_path, min_contour_area=500):
    img = cv2.imread(str(input_path))
    if img is None:
        print(f"⚠️ Could not read {input_path}")
        return False

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _, thresh = cv2.threshold(gray, 10, 255, cv2.THRESH_BINARY)

    # Find contours
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if not contours:
        print(f"⚠️ No contour found in {input_path}")
        return False

    c = max(contours, key=cv2.contourArea)
    if cv2.contourArea(c) < min_contour_area:
        print(f"⚠️ Contour too small in {input_path}")
        return False

    x, y, w, h = cv2.boundingRect(c)
    cropped = img[y:y+h, x:x+w]

    # Ensure output folder exists
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    cv2.imwrite(str(output_path), cropped)
    return True

# ---- Apply cropping recursively ----
def preprocess_dataset(input_dir, output_dir):
    input_dir = Path(input_dir)
    output_dir = Path(output_dir)

    for class_dir in input_dir.iterdir():
        if class_dir.is_dir():
            for img_path in class_dir.glob("*.*"):
                out_path = output_dir / class_dir.name / img_path.name
                crop_black_borders(img_path, out_path)

# %%
INPUT_DIR = 'asteroid_images'
OUTPUT_DIR = 'asteroid_images_cropped'

preprocess_dataset(INPUT_DIR, OUTPUT_DIR)
print("✅ Cropping done, dataset ready in:", OUTPUT_DIR)
# Out:
# ✅ Cropping done, dataset ready in: asteroid_images_cropped

# %%
DATA_DIR = "asteroid_images_cropped"
